# %% [markdown]
# **Titanic 예제로 Pandas, Numpy 학습**

# %%
# 0. Pandas, Numpy 불러오기
import numpy as np
import pandas as pd

# 0-1. Pandas 자료 구조는 대개 Series와 DataFrame이 쓰임.
# Series는 pandas의 기본 블록, 1차원 배열과 같은 자료 구조. 
# Series는 list, dict, NumPy, 스칼라 값으로부터 만들 수 있음

# %%
# 1. .read로 csv로 저장된 데이터 불러오기
df_train = pd.read_csv('train.csv')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2-1. .head()로 앞의 5개만 간략 확인

df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 2-2. .tail()로 뒤의 5개만 간략 확인

df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 3. 속성 확인
type - 타입 확인
.describe()
.index
.values
.value_counts
.value_counts(normalize=True)

# 속성 관련 코드들
.values # 값을 확인 가능
.index # 인덱스 볼 수 있음
.len(s) # 아이템 수 확인
.size # 아이템 수 확인
.unique  # DataFrame에는 쓸 수 없음
.head
.tail
.take([0,9]) # 특정 열 아이템 확인
.iloc[[0, 2]] # 특정 위치 값 찾아 돌려줌
.loc[['PassengerId', 'Pclass']]
.ndim  # 몇차원인지 확인 가능한 속성
.shape # 구조 확인 가능

# %%
print(type(df_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df_train.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df_train.value_counts
# Out:
# <bound method DataFrame.value_counts of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df_train.value_counts(normalize=True)
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 890          1         1       Behr, Mr. Karl Howell                                 male    26.0  0      0      111369    30.0000   C148   C           0.005464
# 337          0         1       Pears, Mr. Thomas Clinton                             male    29.0  1      0      113776    66.6000   C2     S           0.005464
# 332          0         1       Partner, Mr. Austen                                   male    45.5  0      0      113043    28.5000   C124   S           0.005464
# 330          1         1       Hippach, Miss. Jean Gertrude                          female  16.0  0      1      111361    57.9792   B18    C           0.005464
# 328          1         2       Ball, Mrs. (Ada E Hall)                               female  36.0  0      0      28551     13.0000   D      S           0.005464
# ...

# %%
df_train.unique() # Series에만 적용 가능
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-96536006e60a> in <module>
# ----> 1 df_train.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df_train['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df_train.take([0,9])
# Out:
#    PassengerId  Survived  Pclass                                 Name     Sex  \
# 0            1         0       3              Braund, Mr. Owen Harris    male
# 9           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)  female
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  22.0      1      0  A/5 21171   7.2500   NaN        S
# 9  14.0      1      0     237736  30.0708   NaN        C

# %%
df_train.iloc[[0, 2]]
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked
# 0      1      0         A/5 21171  7.250   NaN        S
# 2      0      0  STON/O2. 3101282  7.925   NaN        S

# %%
df_train[['PassengerId', 'Pclass']]
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
# Pclass 종류별 개수 확인하기
df_train.value_counts('Pclass')
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df_train['Pclass'].value_counts(dropna=False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df_train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 특정 컬럼값 수정

# %%
df_train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
type(df_train['Age'])
# Out:
# pandas.core.series.Series

# %%
# 결측치도 세기
df_train['Age'].value_counts(dropna=False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 66.00      1
# 23.50      1
# 0.42       1
# Name: Age, Length: 89, dtype: int64

# %%
s = pd.Series(df_train['Age'].dropna())
s.value_counts(dropna=False)
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
df_train.ndim
# Out:
# 2

# %%
df_train.shape
# Out:
# (891, 12)

# %%
.concat  # 기존 배열에 원소 또는 배열을 추가하여 새 배열을 만들기

# %%
df_train1 = pd.concat([df_train, s])
df_train1
# Out:
#         0   Age Cabin Embarked     Fare  \
# 0     NaN  22.0   NaN        S   7.2500
# 1     NaN  38.0   C85        C  71.2833
# 2     NaN  26.0   NaN        S   7.9250
# 3     NaN  35.0  C123        S  53.1000
# 4     NaN  35.0   NaN        S   8.0500
# ..    ...   ...   ...      ...      ...
# 885  39.0   NaN   NaN      NaN      NaN
# 886  27.0   NaN   NaN      NaN      NaN
# 887  19.0   NaN   NaN      NaN      NaN
# 889  26.0   NaN   NaN      NaN      NaN
# 890  32.0   NaN   NaN      NaN      NaN
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris    0.0          1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0.0          2.0
# 2                               Heikkinen, Miss. Laina    0.0          3.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0.0          4.0
# 4                             Allen, Mr. William Henry    0.0          5.0
# ...

# %%
df_train2 = pd.concat([df_train, s], axis=1)
df_train2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# .sort_values(by='B', ascending=True) 오름차순/내림차순
df_train.sort_values(by='Pclass', ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
# ..           ...       ...     ...
# 379          380         0       3
# 381          382         1       3
# 382          383         0       3
# 371          372         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# .sort_values(by='B', ascending=True) 오름차순/내림차순
df_train.sort_values(by='Pclass', ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 511          512         0       3
# 500          501         0       3
# 501          502         0       3
# 502          503         0       3
# ..           ...       ...     ...
# 102          103         0       1
# 710          711         1       1
# 711          712         0       1
# 712          713         1       1
# 445          446         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 511                                 Webber, Mr. James    male   NaN      0
# 500                                  Calic, Mr. Petar    male  17.0      0
# 501                               Canavan, Miss. Mary  female  21.0      0
# 502                    O'Sullivan, Miss. Bridget Mary  female   NaN      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df_train.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# 특정 부분만 발췌
# index 값으로 DataFrame Slice
# [시작 : 끝-1]

df_train[886:888]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 886          887         0       2         Montvila, Rev. Juozas    male
# 887          888         1       1  Graham, Miss. Margaret Edith  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 886  27.0      0      0  211536  13.0   NaN        S
# 887  19.0      0      0  112053  30.0   B42        S

# %%
a = df_train['Age'] = pd.Series(df_train['Age'], dtype='int64')
a
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# **특정 날짜 기준 DataFrame 생성해보기**

# %%
datas = pd.date_range('20210310', periods=5)
print(datas)
# Out:
# DatetimeIndex(['2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13',
#                '2021-03-14'],
#               dtype='datetime64[ns]', freq='D')

# %%
datas[0]
# Out:
# Timestamp('2021-03-10 00:00:00', freq='D')

# %%
# 연도만 자르기

# datetime64 -> 스트링 변환 -> 연도만 자르기
datas = datas.astype(str)
datas = datas.str[0:4]
type(datas)
datas
# Out:
# Index(['2021', '2021', '2021', '2021', '2021'], dtype='object')

# %%
datas = pd.date_range('20210310', periods=12)
print(datas)
# Out:
# DatetimeIndex(['2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13',
#                '2021-03-14', '2021-03-15', '2021-03-16', '2021-03-17',
#                '2021-03-18', '2021-03-19', '2021-03-20', '2021-03-21'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **난수 발생**

# %%
# 0~1까지의 균일 분포값을 12by4 즉 48개 구성 후에 이미 존재하는 DatetimeIndex를 index로 적용해서 가공된 DataFrame
df = pd.DataFrame(np.random.rand(12, 4))
df
# Out:
#            0         1         2         3
# 0   0.021847  0.732309  0.527515  0.099271
# 1   0.000305  0.797032  0.995788  0.980034
# 2   0.072475  0.756753  0.871282  0.786599
# 3   0.903078  0.816315  0.319440  0.175339
# 4   0.624331  0.732685  0.280844  0.344315
# 5   0.222132  0.444367  0.393214  0.990304
# 6   0.294957  0.705854  0.015232  0.894466
# 7   0.472960  0.316271  0.672048  0.535992
# 8   0.009672  0.891886  0.511443  0.422222
# 9   0.681063  0.680763  0.714929  0.625123
# 10  0.597173  0.556108  0.779664  0.026439
# 11  0.536305  0.744443  0.931283  0.386488

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
np.random.randint(10)   # 10 이하 범위에서 난수값 발생
# Out:
# 5

# %%
# index명, column명 삽입
df = pd.DataFrame(np.random.rand(12, 4), index=datas, columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2021-03-10  0.102165  0.442060  0.754690  0.044466
# 2021-03-11  0.060418  0.137588  0.317981  0.624422
# 2021-03-12  0.764268  0.269381  0.634245  0.191780
# 2021-03-13  0.908370  0.385582  0.487560  0.285273
# 2021-03-14  0.565421  0.865262  0.116763  0.541253
# 2021-03-15  0.914745  0.116104  0.413842  0.158539
# 2021-03-16  0.127291  0.536260  0.978976  0.812752
# 2021-03-17  0.549128  0.832671  0.844861  0.402811
# 2021-03-18  0.538637  0.647111  0.198460  0.258530
# 2021-03-19  0.026992  0.010411  0.457952  0.145454
# 2021-03-20  0.564171  0.645502  0.113958  0.309027
# 2021-03-21  0.675098  0.860911  0.478029  0.141212

# %%
# DataFrame이 보유한 value값들만 반환
df.values
# Out:
# array([[0.1021649 , 0.44206033, 0.75469027, 0.04446574],
#        [0.06041818, 0.13758847, 0.31798079, 0.62442187],
#        [0.76426762, 0.26938081, 0.63424493, 0.1917797 ],
#        [0.90836991, 0.38558225, 0.48755954, 0.28527297],
#        [0.56542067, 0.86526228, 0.11676315, 0.54125305],
#        [0.91474544, 0.1161038 , 0.41384205, 0.15853861],
#        [0.1272909 , 0.53625962, 0.97897621, 0.81275227],
#        [0.54912847, 0.83267116, 0.844861  , 0.40281067],
#        [0.53863734, 0.64711079, 0.1984605 , 0.25853041],
#        [0.02699245, 0.01041139, 0.4579523 , 0.14545442],
#        [0.56417122, 0.64550202, 0.11395763, 0.30902745],
#        [0.67509792, 0.86091113, 0.47802892, 0.14121241]])

# %%
df.index
# Out:
# DatetimeIndex(['2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13',
#                '2021-03-14', '2021-03-15', '2021-03-16', '2021-03-17',
#                '2021-03-18', '2021-03-19', '2021-03-20', '2021-03-21'],
#               dtype='datetime64[ns]', freq='D')
